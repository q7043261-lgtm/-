# %% [markdown]
# <a href="https://colab.research.google.com/github/q7043261-lgtm/-/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 2. Управление ходом выполнения программы

# %% [markdown]
# Насенников Андрей Николаевич ИНБ-б-0-26-1(1)

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Z=\frac{X^2}{1\cdot3}-\frac{X^4}{3\cdot5}+\frac{X^6}{5\cdot7}-\frac{X^8}{7\cdot9}+...$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $X$. Переменная, которая должна быть вычислена на основе независимых: $Z$.
#
# Следует обратить внимание, что в выражении неизвестное число слагаемых, поэтому необходимо ввести переменную $N$ для представления количества слагаемых.
#
# Обратите внимание, что знаки слагаемых чередуются, а степени числителя и множетели знаменателя привязаны к порядковому номеру слагаемого.

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
X = 2
N = 10
Z = 0
for i in range(1, N + 1):
    chis = X ** (2 * i)
    znam = (2 * i - 1) * (2 * i + 1)
    if i % 2 == 1:
        Z += chis / znam
    else:
        Z -= chis / znam
print("X =", X, "тип:", type(X))
print("N =", N, "тип:", type(N))
print("Z =", Z, "тип:", type(Z))
# Out:
# -2.573593073593073

# %% [markdown]
# Решите пример в соответствии с индивидуальным заданием

# %%
# Здесь код индивидуального задания...

# %% [markdown]
# Контрольные вопросы
#
# 1. Что такое переменная?
#
# Переменная — это имя, которое используется для хранения значения в программе. Значение переменной можно изменять во время выполнения программы.
#
# 2. Какие из приведенных ниже имен переменных недопустимы в Python и почему?
#
# - 99bottles — недопустимо, потому что имя переменной не может начинаться с цифры.
# - july2009 — допустимо.
# - theSalesFigureForFiscalYear — допустимо.
# - r&d — недопустимо, потому что символ & нельзя использовать в имени переменной.
# - grade_report — допустимо.
#
# 3. Являются ли имена переменных Sales и sales одинаковыми? Почему?
#
# Нет. Python различает регистр букв, поэтому Sales и sales являются разными именами переменных.
#
# 4. Допустима ли приведенная инструкция присваивания 72 = amount?
#
# Нет, недопустима. В левой части оператора присваивания должно находиться имя переменной, а 72 является числовым значением.
#
# 5. Что покажет приведенный фрагмент кода?
#
# val = 99
# print('Значение равняется', 'val')
#
# Результат:
# Значение равняется val
#
# Поскольку val заключено в кавычки, оно является строкой, а не переменной.
#
# 6. Какой тип данных Python будут иметь эти значения?
#
# value1 = 99
# value2 = 45.9
# value3 = 7.0
# value4 = 7
# value5 = 'abc'
#
# - value1 — int (целое число).
# - value2 — float (вещественное число).
# - value3 — float (вещественное число).
# - value4 — int (целое число).
# - value5 — str (строка).
#
# 7. Что покажет приведенный фрагмент кода?
#
# my_value = 99
# my_value = 0
# print(my_value)
#
# Результат:
# 0
#
# Сначала переменной присваивается значение 99, затем оно заменяется на 0.
#
# 8. Перепишите фрагмент кода с использованием функции range.
#
# for x in range(6):
#     print('Обожаю эту программу!')
#
# 9. Что покажет приведенный фрагмент кода?
#
# for number in range(6):
#     print(number)
#
# Результат:
# 0
# 1
# 2
# 3
# 4
# 5
#
# 10. Что покажет приведенный фрагмент кода?
#
# for number in range(2, 6):
#     print(number)
#
# Результат:
# 2
# 3
# 4
# 5
#
# 11. Что покажет приведенный фрагмент кода?
#
# for number in range(0, 501, 100):
#     print(number)
#
# Результат:
# 0
# 100
# 200
# 300
# 400
# 500
#
# 12. Что покажет приведенный фрагмент кода?
#
# for number in range(10, 5, -1):
#     print(number)
#
# Результат:
# 10
# 9
# 8
# 7
# 6
#
# 13. Что такое накопитель (аккумуляторная переменная)?
#
# Накопитель — это переменная, которая используется для последовательного накопления результата, например суммы или произведения значений в цикле.
#
# 14. Следует ли инициализировать накопитель конкретным значением? Почему или почему нет?
#
# Да. Накопитель необходимо предварительно инициализировать начальным значением. Например, при вычислении суммы обычно используется значение 0:
#
# total = 0
#
# Это необходимо для того, чтобы программа знала начальное значение накопителя.
#
# 15. Что покажет приведенный фрагмент кода?
#
# total = 0
# for count in range(1, 6):
#     total = total + count
# print(total)
#
# Вычисляется сумма:
# 1 + 2 + 3 + 4 + 5 = 15
#
# Результат:
# 15
#
# 16. Что покажет приведенный фрагмент кода?
#
# number1 = 10
# number2 = 5
# number1 = number1 + number2
# print(number1, number2)
#
# Результат:
# 15 5
#
# 17. Перепишите инструкции с использованием расширенных операторов присваивания.
#
# quantity += 1
# days_left -= 5
# price *= 10
# price /= 2
#
# 18. Нужно, чтобы пользователь программы ввел фамилию клиента.
#
# surname = input("Введите фамилию клиента: ")
#
# 19. Нужно, чтобы пользователь программы ввел объем продаж за неделю.
#
# sales = float(input("Введите объем продаж за неделю: "))
#
# 20. Что такое бесконечный цикл? Напишите программный код для бесконечного цикла.
#
# Бесконечный цикл — это цикл, который не имеет условия завершения и выполняется до тех пор, пока программа не будет остановлена.
#
# Пример:
#
# while True:
#     print("Этот цикл выполняется бесконечно")

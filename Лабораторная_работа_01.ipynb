# %% [markdown]
# <a href="https://colab.research.google.com/github/q7043261-lgtm/-/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 1. Простейший скрипт Python

# %% [markdown]
# Насенников Андрей Николаевич ИНБ-б-0-26-1(1)

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$R_x=a\cdot b+\frac{b}{t}-x+f\cdot i_2$$
#
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $x, y, a, k\_to$. Переменная, которая должна быть вычислена на основе независимых: $Z$.

# %%
a = 5
b = 20
t = 4
x = 10
f = 2
i_2 = 3

print("a =", a, ", type(a) =", type(a))
print("b =", b, ", type(b) =", type(b))
print("t =", t, ", type(t) =", type(t))
print("x =", x, ", type(x) =", type(x))
print("f =", f, ", type(f) =", type(f))
print("i_2 =", i_2, ", type(i_2) =", type(i_2))
# Out:
# a = 5 , type(a) = <class 'int'>
# b = 20 , type(b) = <class 'int'>
# t = 4 , type(t) = <class 'int'>
# x = 10 , type(x) = <class 'int'>
# f = 2 , type(f) = <class 'int'>
# i_2 = 3 , type(i_2) = <class 'int'>

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
R_x = a * b + b / t - x + f * i_2

print("R_x =", R_x)
print("Type of R_x:", type(R_x))
# Out:
# R_x = 101.0
# Type of R_x: <class 'float'>

# %% [markdown]
# Основные функции, используемые в данной практической работе: print(), type()

# %% [markdown]
# Контрольные вопросы
#
# 1. Чем отличается интерпретируемый язык программирования от компилируемого?
# Интерпретируемый язык выполняется специальной программой — интерпретатором, который переводит и выполняет код во время работы программы. Компилируемый язык сначала переводится компилятором в машинный код, после чего полученная программа выполняется.
#
# 2. Перечислите компилируемые языки программирования.
# C, C++, C#, Java, Go, Rust, Swift, Fortran.
#
# 3. Перечислите интерпретируемые языки программирования.
# Python, JavaScript, PHP, Ruby, Perl, Bash.
#
# 4. Как объявляются переменные в языке Python?
# Переменная создаётся автоматически при присваивании ей значения. Например:
# x = 10
# name = "Иван"
#
# 5. Каким образом определить тип переменной в языке Python?
# Для определения типа переменной используется функция type():
# x = 10
# print(type(x))
#
# 6. Для чего используется функция print()?
# Функция print() используется для вывода информации на экран.
#
# 7. Какая функция предназначена для вычисления модуля в Python? Какую библиотеку необходимо для этого подключить?
# Для вычисления модуля числа используется функция abs(). Дополнительную библиотеку подключать не нужно.
# Пример:
# abs(-10)  # 10
#
# 8. Какие из перечисленных идентификаторов нельзя использовать в качестве имён пользовательских переменных?
# Нельзя использовать:
# create-var — содержит недопустимый символ "-";
# 4perem — начинается с цифры;
# System.Double — содержит недопустимый символ ".".
#
# int — встроенное имя Python. Технически его можно переопределить, но использовать его в качестве имени собственной переменной не рекомендуется.
#
# 9. Перечислите основные типы в Python.
# Основные типы данных: int — целые числа, float — числа с плавающей точкой, complex — комплексные числа, bool — логический тип, str — строки, list — списки, tuple — кортежи, set — множества, dict — словари.
#
# 10. Как называется программа, которая выполняет специализированную задачу, в частности, такие программы, как вирусный сканер, программа сжатия файлов или программа резервного копирования данных?
# Такая программа называется прикладной программой или прикладным программным обеспечением.
#
# 11. К какой категории программного обеспечения принадлежат программы обработки текста, программы по работе с электронными таблицами, почтовые программы, веб-браузеры и компьютерные игры?
# Они относятся к прикладному программному обеспечению.
#
# 12. Какого объёма памяти достаточно для хранения буквы алфавита или небольшого числа?
# Для хранения одного символа или небольшого числа обычно достаточно 1 байта (8 бит).
#
# 13. В какой системе исчисления все числовые значения записываются как последовательности нулей и единиц?
# В двоичной системе счисления.
#
# 14. Какова задача схемы кодирования ASCII?
# ASCII предназначена для кодирования символов с помощью числовых значений, чтобы компьютер мог хранить и обрабатывать текст.
#
# 15. Какая схема кодирования является достаточно широкой, чтобы включать символы многих языков мира?
# Unicode — универсальный стандарт кодирования символов, включающий символы большинства языков мира.
#
# 16. Что означают термины «цифровые данные» и «цифровое устройство»?
# Цифровые данные — информация, представленная в цифровой форме, обычно в виде последовательности битов.
# Цифровое устройство — устройство, которое обрабатывает, хранит или передаёт информацию в цифровой форме.
#
# 17. ЦП понимает инструкции, которые написаны только на одном языке. Как называется этот язык?
# Этот язык называется машинным языком или машинным кодом.
#
# 18. Как называется тип памяти, в которую программа должна копироваться при каждом её исполнении центральным процессором?
# Это оперативная память (ОЗУ, RAM).
#
# 19. Как называется процесс, в котором участвует ЦП, когда он исполняет инструкции в программе?
# Этот процесс называется выполнением программы или обработкой инструкций.
#
# 20. Что такое язык ассемблера?
# Язык ассемблера — низкоуровневый язык программирования, в котором машинные инструкции записываются с помощью специальных мнемонических обозначений. Специальная программа — ассемблер — переводит их в машинный код.
